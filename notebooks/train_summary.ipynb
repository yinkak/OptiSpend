# %%
import arviz as az

# Load the trace you just saved
trace = az.from_netcdf("../models/mmm_trace.nc")

# Look at the summary for the Betas (ROIs)
summary = az.summary(trace, var_names=["beta_TV_Spend", "beta_YouTube_Spend", "beta_Facebook_Spend", "beta_Instagram_Spend"])
print(summary)
# Out:
#                        mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# beta_TV_Spend         1.234  0.609   0.353    2.340      0.013    0.014
# beta_YouTube_Spend    0.626  0.751   0.000    1.866      0.312    0.020
# beta_Facebook_Spend   0.976  0.692   0.138    2.230      0.230    0.019
# beta_Instagram_Spend  1.193  1.347   0.000    3.422      0.599    0.029
#
#                       ess_bulk  ess_tail  r_hat
# beta_TV_Spend           2282.0    2575.0   1.00
# beta_YouTube_Spend         6.0     109.0   1.73
# beta_Facebook_Spend        8.0     132.0   1.47
# beta_Instagram_Spend       6.0     142.0   1.73
